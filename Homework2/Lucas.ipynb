# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
base_url = "https://www.topuniversities.com"

unis_url = [{'name': 'Massachusetts Institute of Technology (MIT)',
  'url': '/universities/massachusetts-institute-technology-mit'},
 {'name': 'Stanford University', 'url': '/universities/stanford-university'},
 {'name': 'Harvard University', 'url': '/universities/harvard-university'},
 {'name': 'California Institute of Technology (Caltech)',
  'url': '/universities/california-institute-technology-caltech'},
 {'name': 'University of Cambridge',
  'url': '/universities/university-cambridge'},
 {'name': 'University of Oxford', 'url': '/universities/university-oxford'},
 {'name': 'UCL (University College London)',
  'url': '/universities/ucl-university-college-london'},
 {'name': 'Imperial College London',
  'url': '/universities/imperial-college-london'},
 {'name': 'University of Chicago', 'url': '/universities/university-chicago'},
 {'name': 'ETH Zurich - Swiss Federal Institute of Technology',
  'url': '/universities/eth-zurich-swiss-federal-institute-technology'},
 {'name': 'Nanyang Technological University, Singapore (NTU)',
  'url': '/universities/nanyang-technological-university-singapore-ntu'},
 {'name': 'Ecole Polytechnique Fédérale de Lausanne (EPFL)',
  'url': '/universities/ecole-polytechnique-f%C3%A9d%C3%A9rale-de-lausanne-epfl'},
 {'name': 'Princeton University', 'url': '/universities/princeton-university'},
 {'name': 'Cornell University', 'url': '/universities/cornell-university'},
 {'name': 'National University of Singapore (NUS)',
  'url': '/universities/national-university-singapore-nus'},
 {'name': 'Yale University', 'url': '/universities/yale-university'},
 {'name': 'Johns Hopkins University',
  'url': '/universities/johns-hopkins-university'},
 {'name': 'Columbia University', 'url': '/universities/columbia-university'},
 {'name': 'University of Pennsylvania',
  'url': '/universities/university-pennsylvania'},
 {'name': 'The Australian National University',
  'url': '/universities/australian-national-university'},
 {'name': 'Duke University', 'url': '/universities/duke-university'},
 {'name': 'University of Michigan',
  'url': '/universities/university-michigan'},
 {'name': "King's College London",
  'url': '/universities/kings-college-london'},
 {'name': 'The University of Edinburgh',
  'url': '/universities/university-edinburgh'},
 {'name': 'Tsinghua University', 'url': '/universities/tsinghua-university'},
 {'name': 'The University of Hong Kong',
  'url': '/universities/university-hong-kong'},
 {'name': 'University of California, Berkeley (UCB)',
  'url': '/universities/university-california-berkeley-ucb'},
 {'name': 'Northwestern University',
  'url': '/universities/northwestern-university'},
 {'name': 'The University of Tokyo', 'url': '/universities/university-tokyo'},
 {'name': 'The Hong Kong University of Science and Technology',
  'url': '/universities/hong-kong-university-science-technology'},
 {'name': 'University of Toronto', 'url': '/universities/university-toronto'},
 {'name': 'McGill University', 'url': '/universities/mcgill-university'},
 {'name': 'University of California, Los Angeles (UCLA)',
  'url': '/universities/university-california-los-angeles-ucla'},
 {'name': 'The University of Manchester',
  'url': '/universities/university-manchester'},
 {'name': 'London School of Economics and Political Science (LSE)',
  'url': '/universities/london-school-economics-political-science-lse'},
 {'name': 'Kyoto University', 'url': '/universities/kyoto-university'},
 {'name': 'Seoul National University',
  'url': '/universities/seoul-national-university'},
 {'name': 'Peking University', 'url': '/universities/peking-university'},
 {'name': 'University of California, San Diego (UCSD)',
  'url': '/universities/university-california-san-diego-ucsd'},
 {'name': 'Fudan University', 'url': '/universities/fudan-university'},
 {'name': 'KAIST - Korea Advanced Institute of Science & Technology',
  'url': '/universities/kaist-korea-advanced-institute-science-technology'},
 {'name': 'The University of Melbourne',
  'url': '/universities/university-melbourne'},
 {'name': 'Ecole normale supérieure, Paris',
  'url': '/universities/ecole-normale-sup%C3%A9rieure-paris'},
 {'name': 'University of Bristol', 'url': '/universities/university-bristol'},
 {'name': 'The University of New South Wales (UNSW Sydney)',
  'url': '/universities/university-new-south-wales-unsw-sydney'},
 {'name': 'The Chinese University of Hong Kong (CUHK)',
  'url': '/universities/chinese-university-hong-kong-cuhk'},
 {'name': 'The University of Queensland',
  'url': '/universities/university-queensland'},
 {'name': 'Carnegie Mellon University',
  'url': '/universities/carnegie-mellon-university'},
 {'name': 'City University of Hong Kong',
  'url': '/universities/city-university-hong-kong'},
 {'name': 'The University of Sydney',
  'url': '/universities/university-sydney'},
 {'name': 'University of British Columbia',
  'url': '/universities/university-british-columbia'},
 {'name': 'New York University (NYU)',
  'url': '/universities/new-york-university-nyu'},
 {'name': 'Brown University', 'url': '/universities/brown-university'},
 {'name': 'Delft University of Technology',
  'url': '/universities/delft-university-technology'},
 {'name': 'University of Wisconsin-Madison',
  'url': '/universities/university-wisconsin-madison'},
 {'name': 'Tokyo Institute of Technology',
  'url': '/universities/tokyo-institute-technology'},
 {'name': 'The University of Warwick',
  'url': '/universities/university-warwick'},
 {'name': 'University of Amsterdam',
  'url': '/universities/university-amsterdam'},
 {'name': 'Ecole Polytechnique', 'url': '/universities/ecole-polytechnique'},
 {'name': 'Monash University', 'url': '/universities/monash-university'},
 {'name': 'University of Washington',
  'url': '/universities/university-washington'},
 {'name': 'Shanghai Jiao Tong University',
  'url': '/universities/shanghai-jiao-tong-university'},
 {'name': 'Osaka University', 'url': '/universities/osaka-university'},
 {'name': 'Technical University of Munich',
  'url': '/universities/technical-university-munich'},
 {'name': 'University of Glasgow', 'url': '/universities/university-glasgow'},
 {'name': 'Ludwig-Maximilians-Universität München',
  'url': '/universities/ludwig-maximilians-universit%C3%A4t-m%C3%BCnchen'},
 {'name': 'University of Texas at Austin',
  'url': '/universities/university-texas-austin'},
 {'name': 'Ruprecht-Karls-Universität Heidelberg',
  'url': '/universities/ruprecht-karls-universit%C3%A4t-heidelberg'},
 {'name': 'University of Illinois at Urbana-Champaign',
  'url': '/universities/university-illinois-urbana-champaign'},
 {'name': 'Georgia Institute of Technology',
  'url': '/universities/georgia-institute-technology'},
 {'name': 'KU Leuven', 'url': '/universities/ku-leuven'},
 {'name': 'Pohang University of Science And Technology (POSTECH)',
  'url': '/universities/pohang-university-science-technology-postech'},
 {'name': 'University of Zurich', 'url': '/universities/university-zurich'},
 {'name': 'University of Copenhagen',
  'url': '/universities/university-copenhagen'},
 {'name': 'Universidad de Buenos Aires (UBA)',
  'url': '/universities/universidad-de-buenos-aires-uba'},
 {'name': 'National Taiwan University (NTU)',
  'url': '/universities/national-taiwan-university-ntu'},
 {'name': 'Tohoku University', 'url': '/universities/tohoku-university'},
 {'name': 'Lund University', 'url': '/universities/lund-university'},
 {'name': 'Durham University', 'url': '/universities/durham-university'},
 {'name': 'University of North Carolina, Chapel Hill',
  'url': '/universities/university-north-carolina-chapel-hill'},
 {'name': 'Boston University', 'url': '/universities/boston-university'},
 {'name': 'The University of Auckland',
  'url': '/universities/university-auckland'},
 {'name': 'The University of Sheffield',
  'url': '/universities/university-sheffield'},
 {'name': 'The University of Nottingham',
  'url': '/universities/university-nottingham'},
 {'name': 'University of Birmingham',
  'url': '/universities/university-birmingham'},
 {'name': 'The Ohio State University',
  'url': '/universities/ohio-state-university'},
 {'name': 'Zhejiang University', 'url': '/universities/zhejiang-university'},
 {'name': 'Trinity College Dublin, The University of Dublin',
  'url': '/universities/trinity-college-dublin-university-dublin'},
 {'name': 'Rice University', 'url': '/universities/rice-university'},
 {'name': 'University of Alberta', 'url': '/universities/university-alberta'},
 {'name': 'Korea University', 'url': '/universities/korea-university'},
 {'name': 'University of St Andrews',
  'url': '/universities/university-st-andrews'},
 {'name': 'Pennsylvania State University',
  'url': '/universities/pennsylvania-state-university'},
 {'name': 'The University of Western Australia',
  'url': '/universities/university-western-australia'},
 {'name': 'The Hong Kong Polytechnic University',
  'url': '/universities/hong-kong-polytechnic-university'},
 {'name': 'Lomonosov Moscow State University',
  'url': '/universities/lomonosov-moscow-state-university'},
 {'name': 'University of Science and Technology of China',
  'url': '/universities/university-science-technology-china'},
 {'name': 'KTH Royal Institute of Technology',
  'url': '/universities/kth-royal-institute-technology'},
 {'name': 'University of Geneva', 'url': '/universities/university-geneva'},
 {'name': 'Washington University in St. Louis',
  'url': '/universities/washington-university-st-louis'},
 {'name': 'University of Leeds', 'url': '/universities/university-leeds'},
 {'name': 'University of Southampton',
  'url': '/universities/university-southampton'},
 {'name': 'University of Helsinki',
  'url': '/universities/university-helsinki'},
 {'name': 'Eindhoven University of Technology',
  'url': '/universities/eindhoven-university-technology'},
 {'name': 'Purdue University', 'url': '/universities/purdue-university'},
 {'name': 'Yonsei University', 'url': '/universities/yonsei-university'},
 {'name': 'KIT, Karlsruhe Institute of Technology',
  'url': '/universities/kit-karlsruhe-institute-technology'},
 {'name': 'Sungkyunkwan University (SKKU)',
  'url': '/universities/sungkyunkwan-university-skku'},
 {'name': 'The University of Adelaide',
  'url': '/universities/university-adelaide'},
 {'name': 'Utrecht University', 'url': '/universities/utrecht-university'},
 {'name': 'Leiden University', 'url': '/universities/leiden-university'},
 {'name': 'Uppsala University', 'url': '/universities/uppsala-university'},
 {'name': 'University of Groningen',
  'url': '/universities/university-groningen'},
 {'name': 'Universiti Malaya (UM)',
  'url': '/universities/universiti-malaya-um'},
 {'name': 'Nanjing University', 'url': '/universities/nanjing-university'},
 {'name': 'Nagoya University', 'url': '/universities/nagoya-university'},
 {'name': 'Technical University of Denmark',
  'url': '/universities/technical-university-denmark'},
 {'name': 'University of California, Davis',
  'url': '/universities/university-california-davis'},
 {'name': 'Aarhus University', 'url': '/universities/aarhus-university'},
 {'name': 'Humboldt-Universität zu Berlin',
  'url': '/universities/humboldt-universit%C3%A4t-zu-berlin'},
 {'name': 'Universidade de São Paulo',
  'url': '/universities/universidade-de-s%C3%A3o-paulo'},
 {'name': 'Universidad Nacional Autónoma de México  (UNAM)',
  'url': '/universities/universidad-nacional-aut%C3%B3noma-de-m%C3%A9xico-unam'},
 {'name': 'Hokkaido University', 'url': '/universities/hokkaido-university'},
 {'name': 'Wageningen University',
  'url': '/universities/wageningen-university'},
 {'name': 'Freie Universitaet Berlin',
  'url': '/universities/freie-universitaet-berlin'},
 {'name': 'Ghent University', 'url': '/universities/ghent-university'},
 {'name': 'Queen Mary University of London',
  'url': '/universities/queen-mary-university-london'},
 {'name': 'Kyushu University', 'url': '/universities/kyushu-university'},
 {'name': 'University of Maryland, College Park',
  'url': '/universities/university-maryland-college-park'},
 {'name': 'Université de Montréal',
  'url': '/universities/universit%C3%A9-de-montr%C3%A9al'},
 {'name': 'Université Pierre et Marie Curie (UPMC)',
  'url': '/universities/universit%C3%A9-pierre-et-marie-curie-upmc'},
 {'name': 'University of Southern California',
  'url': '/universities/university-southern-california'},
 {'name': 'Chalmers University of Technology',
  'url': '/universities/chalmers-university-technology'},
 {'name': 'University of California, Santa Barbara (UCSB)',
  'url': '/universities/university-california-santa-barbara-ucsb'},
 {'name': 'Lancaster University', 'url': '/universities/lancaster-university'},
 {'name': 'University of York', 'url': '/universities/university-york'},
 {'name': 'Aalto University', 'url': '/universities/aalto-university'},
 {'name': 'Cardiff University', 'url': '/universities/cardiff-university'},
 {'name': 'Pontificia Universidad Católica de Chile (UC)',
  'url': '/universities/pontificia-universidad-cat%C3%B3lica-de-chile-uc'},
 {'name': 'McMaster University', 'url': '/universities/mcmaster-university'},
 {'name': 'RWTH Aachen University',
  'url': '/universities/rwth-aachen-university'},
 {'name': 'University of Oslo', 'url': '/universities/university-oslo'},
 {'name': 'University of Pittsburgh',
  'url': '/universities/university-pittsburgh'},
 {'name': 'Technische Universität Berlin (TU Berlin)',
  'url': '/universities/technische-universit%C3%A4t-berlin-tu-berlin'},
 {'name': 'The Hebrew University of Jerusalem',
  'url': '/universities/hebrew-university-jerusalem'},
 {'name': 'University of Lausanne',
  'url': '/universities/university-lausanne'},
 {'name': 'Emory University', 'url': '/universities/emory-university'},
 {'name': 'Erasmus University Rotterdam',
  'url': '/universities/erasmus-university-rotterdam'},
 {'name': 'University of Basel', 'url': '/universities/university-basel'},
 {'name': 'Michigan State University',
  'url': '/universities/michigan-state-university'},
 {'name': 'University of Otago', 'url': '/universities/university-otago'},
 {'name': 'University of Waterloo',
  'url': '/universities/university-waterloo'},
 {'name': 'Université catholique de Louvain (UCL)',
  'url': '/universities/universit%C3%A9-catholique-de-louvain-ucl'},
 {'name': 'University of Vienna', 'url': '/universities/university-vienna'},
 {'name': 'Hanyang University', 'url': '/universities/hanyang-university'},
 {'name': 'Universitat de Barcelona',
  'url': '/universities/universitat-de-barcelona'},
 {'name': 'École Normale Supérieure de Lyon',
  'url': '/universities/%C3%A9cole-normale-sup%C3%A9rieure-de-lyon'},
 {'name': 'The University of Exeter',
  'url': '/universities/university-exeter'},
 {'name': 'University of Aberdeen',
  'url': '/universities/university-aberdeen'},
 {'name': 'University of Bath', 'url': '/universities/university-bath'},
 {'name': 'Newcastle University', 'url': '/universities/newcastle-university'},
 {'name': 'National Tsing Hua University',
  'url': '/universities/national-tsing-hua-university'},
 {'name': 'University of Minnesota',
  'url': '/universities/university-minnesota'},
 {'name': 'Eberhard Karls Universität Tübingen',
  'url': '/universities/eberhard-karls-universit%C3%A4t-t%C3%BCbingen'},
 {'name': 'University of California, Irvine',
  'url': '/universities/university-california-irvine'},
 {'name': 'University of Bergen', 'url': '/universities/university-bergen'},
 {'name': 'University of Bern', 'url': '/universities/university-bern'},
 {'name': 'University College Dublin',
  'url': '/universities/university-college-dublin'},
 {'name': 'Dartmouth College', 'url': '/universities/dartmouth-college'},
 {'name': 'Politecnico di Milano',
  'url': '/universities/politecnico-di-milano'},
 {'name': 'Albert-Ludwigs-Universitaet Freiburg',
  'url': '/universities/albert-ludwigs-universitaet-freiburg'},
 {'name': 'Indian Institute of Technology Delhi (IITD)',
  'url': '/universities/indian-institute-technology-delhi-iitd'},
 {'name': 'University of Virginia',
  'url': '/universities/university-virginia'},
 {'name': 'King Fahd University of Petroleum & Minerals',
  'url': '/universities/king-fahd-university-petroleum-minerals'},
 {'name': 'University of Liverpool',
  'url': '/universities/university-liverpool'},
 {'name': 'University of Technology Sydney',
  'url': '/universities/university-technology-sydney'},
 {'name': 'CentraleSupélec', 'url': '/universities/centralesup%C3%A9lec'},
 {'name': 'University of Florida', 'url': '/universities/university-florida'},
 {'name': 'University of Twente', 'url': '/universities/university-twente'},
 {'name': 'Indian Institute of Technology Bombay (IITB)',
  'url': '/universities/indian-institute-technology-bombay-iitb'},
 {'name': 'University of Göttingen',
  'url': '/universities/university-g%C3%B6ttingen'},
 {'name': 'Vrije Universiteit Brussel (VUB)',
  'url': '/universities/vrije-universiteit-brussel-vub'},
 {'name': 'Universidade Estadual de Campinas (Unicamp)',
  'url': '/universities/universidade-estadual-de-campinas-unicamp'},
 {'name': 'University of Colorado Boulder',
  'url': '/universities/university-colorado-boulder'},
 {'name': 'Vienna University of Technology',
  'url': '/universities/vienna-university-technology'},
 {'name': 'University of Rochester',
  'url': '/universities/university-rochester'},
 {'name': 'Universidad Autónoma de Madrid',
  'url': '/universities/universidad-aut%C3%B3noma-de-madrid'},
 {'name': 'Alma Mater Studiorum - University of Bologna',
  'url': '/universities/alma-mater-studiorum-university-bologna'},
 {'name': 'University of Reading', 'url': '/universities/university-reading'},
 {'name': 'Indian Institute of Science (IISc) Bangalore',
  'url': '/universities/indian-institute-science-iisc-bangalore'},
 {'name': 'University of Cape Town',
  'url': '/universities/university-cape-town'},
 {'name': 'Scuola Normale Superiore di Pisa',
  'url': '/universities/scuola-normale-superiore-di-pisa'},
 {'name': "Scuola Superiore Sant'Anna Pisa di Studi Universitari e di Perfezionamento",
  'url': '/universities/scuola-superiore-santanna-pisa-di-studi-universitari-e-di-perfezionamento'},
 {'name': 'Keio University', 'url': '/universities/keio-university'},
 {'name': 'Stockholm University', 'url': '/universities/stockholm-university'},
 {'name': 'Universitat Autònoma de Barcelona',
  'url': '/universities/universitat-aut%C3%B2noma-de-barcelona'},
 {'name': 'Texas A&M University', 'url': '/universities/texas-am-university'},
 {'name': 'Instituto Tecnológico y de Estudios Superiores de Monterrey',
  'url': '/universities/instituto-tecnol%C3%B3gico-y-de-estudios-superiores-de-monterrey'},
 {'name': 'Maastricht University',
  'url': '/universities/maastricht-university'},
 {'name': 'Universidad de Chile', 'url': '/universities/universidad-de-chile'}]

# %%
dictlist = []
def nice_format(number):
    return number.strip('\n').replace(',','')
for url in unis_url[:200]:
    #print(url['name'])
    r = requests.get(base_url+url['url'])
    body = r.text
    soup = BeautifulSoup(body, 'html.parser')
    number = soup.find_all('div', class_='number')
    if len(number) is not 0:
        dictlist.append({'Name': url['name'], 'Total faculty members': nice_format(number[0].text), 'International faculty members'
                        : nice_format(number[1].text), 'Total number of students': nice_format(number[2].text), 'Total number of international students'
                        : nice_format(number[3].text)})
#pd.DataFrame(dictlist).set_index('Name')

# %%
df = pd.DataFrame(dictlist).set_index('Name')
df['Website'] = 'Top Universities'
df
# Out:
#                                                    International faculty members  \
# Name
# Massachusetts Institute of Technology (MIT)                                1679
# Stanford University                                                        2042
# Harvard University                                                         1311
# California Institute of Technology (Caltech)                                350
# University of Cambridge                                                    2278
# University of Oxford                                                       2964
# UCL (University College London)                                            2554
# Imperial College London                                                    2071
# University of Chicago                                                       635
# ETH Zurich - Swiss Federal Institute of Technology                         1886
# Nanyang Technological University, Singapore (NTU)                          2993
# ...

# %% [markdown]
# ## Times higher education

# %%
json_th = requests.get('https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json').json()
data_th = json_th['data']
th_disct = []
for d in data_th[:200]:
    name = d['name']
    total_stu = float(d['stats_number_students'].replace(',', ''))
    inter_percent = float(d['stats_pc_intl_students'].strip('%'))
    student_staff_ratio = float(d['stats_student_staff_ratio'])
    th_disct.append({'Name': name, 'Total number of students': total_stu, 'Total number of international students': (total_stu/100)*inter_percent, 'Total falculty members': total_stu/student_staff_ratio})
df = pd.DataFrame(th_disct).set_index('Name').astype('int64')
df['Website'] = "Times Higher Education"
df['International faculty members'] = np.NAN

# %%
df
# Out:
#                                                     Total falculty members  \
# Name
# University of Oxford                                                  1822
# University of Cambridge                                               1687
# California Institute of Technology                                     339
# Stanford University                                                   2112
# Massachusetts Institute of Technology                                 1284
# Harvard University                                                    2283
# Princeton University                                                   958
# Imperial College London                                               1390
# University of Chicago                                                 2181
# ETH Zurich – Swiss Federal Institute of Technol...                    1317
# University of Pennsylvania                                            3132
# ...
